# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("cm.jpg", cv2.COLOR_BGR2GRAY )
img = img[:,:,0]

# %%
img.shape
# Out:
# (225, 224)

# %%
plt.imshow(img, cmap="gray")

# %%
E = cv2.Canny(img, 500,500)

# %%
plt.imshow(E, cmap="gray")
